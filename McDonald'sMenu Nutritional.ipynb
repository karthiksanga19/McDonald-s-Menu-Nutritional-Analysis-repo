# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\laksh\Downloads\Nutrical Dataset.csv")

# %%
# Display the first few rows of the dataset
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# Category                         0
# Item                             0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# Protein                          0
# Vitamin A (% Daily Value)        0
# Vitamin C (% Daily Value)        0
# Calcium (% Daily Value)          0
# Iron (% Daily Value)             0
# dtype: int64

# %%
# Drop rows with missing values (if applicable)
df = df.dropna()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(df.columns)
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
# Check for data types and missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Category                         0
# Item                             0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# Protein                          0
# Vitamin A (% Daily Value)        0
# Vitamin C (% Daily Value)        0
# Calcium (% Daily Value)          0
# Iron (% Daily Value)             0
# dtype: int64

# %%
# Plot the distribution of calorie counts
plt.figure(figsize=(10, 6))
sns.histplot(df['Calories'], bins=30, kde=True, color='blue')
plt.title('Distribution of Calories Across Menu Items')
plt.xlabel('Calories')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot distribution of Total Fat
plt.figure(figsize=(10, 6))
sns.histplot(df['Total Fat'], bins=30, kde=True, color='red')
plt.title('Distribution of Total Fat Across Menu Items')
plt.xlabel('Total Fat (g)')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot distribution of Protein
plt.figure(figsize=(10, 6))
sns.histplot(df['Protein'], bins=30, kde=True, color='green')
plt.title('Distribution of Protein Across Menu Items')
plt.xlabel('Protein (g)')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot distribution of Carbohydrates
plt.figure(figsize=(10, 6))
sns.histplot(df['Carbohydrates'], bins=30, kde=True, color='orange')
plt.title('Distribution of Carbohydrates Across Menu Items')
plt.xlabel('Carbohydrates (g)')
plt.ylabel('Frequency')
plt.show()

# %%
# Scatter plot for Calories vs. Total Fat
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Total Fat', y='Calories', data=df, hue='Category', palette='viridis')
plt.title('Calories vs. Total Fat')
plt.xlabel('Total Fat (g)')
plt.ylabel('Calories')
plt.show()

# %%
# Pair plot for multiple relationships
sns.pairplot(df[['Calories', 'Total Fat', 'Protein', 'Carbohydrates']], kind='scatter', diag_kind='kde')
plt.suptitle('Pair Plot for Nutritional Components')
plt.show()

# %%
# Plot of Vitamin A, C, Calcium, Iron % Daily Values
plt.figure(figsize=(12, 8))
df[['Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']].mean().plot(kind='bar', color=['skyblue', 'green', 'orange', 'red'])
plt.title('Average % Daily Values for Vitamins and Minerals')
plt.ylabel('Average % Daily Value')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(df.dtypes)
# Out:
# Category                          object
# Item                              object
# Serving Size                      object
# Calories                           int64
# Calories from Fat                  int64
# Total Fat                        float64
# Total Fat (% Daily Value)          int64
# Saturated Fat                    float64
# Saturated Fat (% Daily Value)      int64
# Trans Fat                        float64
# Cholesterol                        int64
# Cholesterol (% Daily Value)        int64
# Sodium                             int64
# Sodium (% Daily Value)             int64
# Carbohydrates                      int64
# Carbohydrates (% Daily Value)      int64
# Dietary Fiber                      int64
# Dietary Fiber (% Daily Value)      int64
# Sugars                             int64
# Protein                            int64
# Vitamin A (% Daily Value)          int64
# Vitamin C (% Daily Value)          int64
# Calcium (% Daily Value)            int64
# ...

# %%
# List of columns that are numeric and relevant for analysis
numeric_columns = [
    'Calories', 'Total Fat', 'Protein', 'Carbohydrates'
]

# Group data by category and calculate mean values for relevant columns
category_means = df.groupby('Category')[numeric_columns].mean()

# Plot bar charts for each nutritional characteristic
category_means.plot(kind='bar', figsize=(12, 8), colormap='viridis')
plt.title('Mean Nutritional Values by Food Category')
plt.ylabel('Mean Value')
plt.xticks(rotation=45)
plt.show()

# %%
# Histogram for Calories
plt.figure(figsize=(10, 6))
sns.histplot(df['Calories'], bins=30, kde=True, color='blue')
plt.title('Distribution of Calories Across Menu Items')
plt.xlabel('Calories')
plt.ylabel('Frequency')
plt.show()

# %%
# Box plot for Calories by Category
plt.figure(figsize=(12, 8))
sns.boxplot(x='Category', y='Calories', data=df, palette='Set3')
plt.title('Calories Distribution by Food Category')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_8092\4202178923.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Category', y='Calories', data=df, palette='Set3')

# %%
# Box plot for Total Fat by Category
plt.figure(figsize=(12, 8))
sns.boxplot(x='Category', y='Total Fat', data=df, palette='Set2')
plt.title('Total Fat Distribution by Food Category')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_8092\387761102.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Category', y='Total Fat', data=df, palette='Set2')

# %%
# Box plot for Protein by Category
plt.figure(figsize=(12, 8))
sns.boxplot(x='Category', y='Protein', data=df, palette='Set1')
plt.title('Protein Distribution by Food Category')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_8092\265842861.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Category', y='Protein', data=df, palette='Set1')

# %%
# Box plot for Carbohydrates by Category
plt.figure(figsize=(12, 8))
sns.boxplot(x='Category', y='Carbohydrates', data=df, palette='coolwarm')
plt.title('Carbohydrates Distribution by Food Category')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_8092\2133294673.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Category', y='Carbohydrates', data=df, palette='coolwarm')

# %%
# Create a figure with subplots
plt.figure(figsize=(15, 12))

# Subplot for Calories
plt.subplot(2, 2, 1)
sns.barplot(x='Category', y='Calories', data=df, ci=None, palette='viridis')
plt.title('Average Calories by Category')
plt.xticks(rotation=45)
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_8092\3227258834.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Category', y='Calories', data=df, ci=None, palette='viridis')
# C:\Users\laksh\AppData\Local\Temp\ipykernel_8092\3227258834.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Category', y='Calories', data=df, ci=None, palette='viridis')
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Breakfast'),
#   Text(1, 0, 'Beef & Pork'),
#   Text(2, 0, 'Chicken & Fish'),
#   Text(3, 0, 'Salads'),
#   Text(4, 0, 'Snacks & Sides'),
#   Text(5, 0, 'Desserts'),
#   Text(6, 0, 'Beverages'),
#   Text(7, 0, 'Coffee & Tea'),
#   Text(8, 0, 'Smoothies & Shakes')])

# %%
# Subplot for Total Fat
plt.subplot(2, 2, 2)
sns.barplot(x='Category', y='Total Fat', data=df, ci=None, palette='Set2')
plt.title('Average Total Fat by Category')
plt.xticks(rotation=45)
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_8092\1864264328.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Category', y='Total Fat', data=df, ci=None, palette='Set2')
# C:\Users\laksh\AppData\Local\Temp\ipykernel_8092\1864264328.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Category', y='Total Fat', data=df, ci=None, palette='Set2')
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Breakfast'),
#   Text(1, 0, 'Beef & Pork'),
#   Text(2, 0, 'Chicken & Fish'),
#   Text(3, 0, 'Salads'),
#   Text(4, 0, 'Snacks & Sides'),
#   Text(5, 0, 'Desserts'),
#   Text(6, 0, 'Beverages'),
#   Text(7, 0, 'Coffee & Tea'),
#   Text(8, 0, 'Smoothies & Shakes')])

# %%
# Subplot for Protein
plt.subplot(2, 2, 3)
sns.barplot(x='Category', y='Protein', data=df, ci=None, palette='Set1')
plt.title('Average Protein by Category')
plt.xticks(rotation=45)
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_8092\3313983603.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Category', y='Protein', data=df, ci=None, palette='Set1')
# C:\Users\laksh\AppData\Local\Temp\ipykernel_8092\3313983603.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Category', y='Protein', data=df, ci=None, palette='Set1')
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Breakfast'),
#   Text(1, 0, 'Beef & Pork'),
#   Text(2, 0, 'Chicken & Fish'),
#   Text(3, 0, 'Salads'),
#   Text(4, 0, 'Snacks & Sides'),
#   Text(5, 0, 'Desserts'),
#   Text(6, 0, 'Beverages'),
#   Text(7, 0, 'Coffee & Tea'),
#   Text(8, 0, 'Smoothies & Shakes')])

# %%
# Subplot for Carbohydrates
plt.subplot(2, 2, 4)
sns.barplot(x='Category', y='Carbohydrates', data=df, ci=None, palette='coolwarm')
plt.title('Average Carbohydrates by Category')
plt.xticks(rotation=45)
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_8092\1156063147.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Category', y='Carbohydrates', data=df, ci=None, palette='coolwarm')
# C:\Users\laksh\AppData\Local\Temp\ipykernel_8092\1156063147.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Category', y='Carbohydrates', data=df, ci=None, palette='coolwarm')
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Breakfast'),
#   Text(1, 0, 'Beef & Pork'),
#   Text(2, 0, 'Chicken & Fish'),
#   Text(3, 0, 'Salads'),
#   Text(4, 0, 'Snacks & Sides'),
#   Text(5, 0, 'Desserts'),
#   Text(6, 0, 'Beverages'),
#   Text(7, 0, 'Coffee & Tea'),
#   Text(8, 0, 'Smoothies & Shakes')])

# %%
plt.tight_layout()
plt.show()

# %%
# Find the menu item with the highest calorie count
highest_calorie_item = df.loc[df['Calories'].idxmax()]
print("Menu item with the highest calorie count:")
print(highest_calorie_item[['Category', 'Item', 'Calories']])
# Out:
# Menu item with the highest calorie count:
# Category                  Chicken & Fish
# Item        Chicken McNuggets (40 piece)
# Calories                            1880
# Name: 82, dtype: object

# %%
# Find the menu item with the lowest calorie count
lowest_calorie_item = df.loc[df['Calories'].idxmin()]
print("\nMenu item with the lowest calorie count:")
print(lowest_calorie_item[['Category', 'Item', 'Calories']])
# Out:
# Menu item with the lowest calorie count:
# Category            Beverages
# Item        Diet Coke (Small)
# Calories                    0
# Name: 114, dtype: object

# %%
# List of columns that are numeric and relevant for analysis
numeric_columns = [
    'Calories', 'Calories from Fat', 'Total Fat', 'Total Fat (% Daily Value)',
    'Saturated Fat', 'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
    'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)', 'Carbohydrates',
    'Carbohydrates (% Daily Value)', 'Dietary Fiber', 'Dietary Fiber (% Daily Value)',
    'Sugars', 'Protein', 'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
    'Calcium (% Daily Value)', 'Iron (% Daily Value)'
]

# Calculate the average nutritional content for each category
average_nutritional_content = df.groupby('Category')[numeric_columns].mean()

print("\nAverage nutritional content of popular menu categories:")
print(average_nutritional_content)
# Out:
# Average nutritional content of popular menu categories:
#                       Calories  Calories from Fat  Total Fat  \
# Category
# Beef & Pork         494.000000         224.666667  24.866667
# Beverages           113.703704           0.740741   0.092593
# Breakfast           526.666667         248.928571  27.690476
# Chicken & Fish      552.962963         242.222222  26.962963
# Coffee & Tea        283.894737          71.105263   8.021053
# Desserts            222.142857          64.285714   7.357143
# Salads              270.000000         108.333333  11.750000
# Smoothies & Shakes  531.428571         127.678571  14.125000
# Snacks & Sides      245.769231          94.615385  10.538462
#
#                     Total Fat (% Daily Value)  Saturated Fat  \
# Category
# Beef & Pork                         38.600000      10.466667
# Beverages                            0.148148       0.055556
# Breakfast                           42.666667      10.654762
# ...

# %%
# Plot the average nutritional content for each category
average_nutritional_content.plot(kind='bar', figsize=(15, 8), colormap='viridis')
plt.title('Average Nutritional Content by Food Category')
plt.ylabel('Mean Nutritional Value')
plt.xticks(rotation=45)
plt.show()
